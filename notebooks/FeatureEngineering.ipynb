# %%
# Create new column: Profit margin
df['ProfitMargin'] = df['Profit'] / df['Sales']

# Check correlation between features
df.corr()

# Visualize Profit vs ProfitMargin
df.plot(kind='scatter', x='Sales', y='ProfitMargin')
plt.show()
